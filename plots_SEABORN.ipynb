# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Gaura\\OneDrive\\Desktop\\tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.size
# Out:
# 1708

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info() #by this we get the data type and we will decide that what kind of action should be take
          #for the continuous data and discrete data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.isnull().sum() #checking if there is any values that are empty
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['sex'].value_counts() #if in the column there are two kinds of data we will get the count of that data
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
#printing the histogram
plt.hist(df['total_bill'])
plt.xlabel('no of people')
plt.ylabel('amount paid')
plt.title('Total_bill histogram')
# Out:
# Text(0.5, 1.0, 'Total_bill histogram')

# %%
sns.displot(df['total_bill'],bins = 10,kde = True)
plt.show() #as we can see that from 10 -20 they are paying more bill

# %%
sns.boxplot(x = 'total_bill',data = df)
plt.show()#as we can see that there are many outiers

# %%
sns.scatterplot(x = 'total_bill',y = 'tip',data = df,hue = 'smoker')
plt.show()

# %%
sns.relplot(x = 'total_bill',y = 'tip',data = df,hue = 'smoker')
plt.show()

# %%
sns.scatterplot(x = 'total_bill',y = 'tip',data = df,style = 'smoker')
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'smoker', style = 'time',col = 'size')
plt.show()

# %%
df['sno'] = pd.DataFrame(np.arange(1,245))
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  sno
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    2
# 2         21.01  3.50    Male     No   Sun  Dinner     3    3
# 3         23.68  3.31    Male     No   Sun  Dinner     2    4
# 4         24.59  3.61  Female     No   Sun  Dinner     4    5
# ..          ...   ...     ...    ...   ...     ...   ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  240
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  241
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  242
# 242       17.82  1.75    Male     No   Sat  Dinner     2  243
# 243       18.78  3.00  Female     No  Thur  Dinner     2  244
#
# [244 rows x 8 columns]

# %%
sns.relplot(x = 'sno',y = 'tip',kind = 'line',data = df)
plt.show()

# %%
df.drop('sno',axis = 1,inplace = True)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x = 'total_bill',y = 'tip',data = df,kind = 'reg') #by default the kind is set to scatter
plt.show()

# %%
sns.violinplot(x = 'total_bill', y = 'day',data = df)
plt.show()

# %%
sns.violinplot(x = 'total_bill',y = 'day',data = df,palette = 'rainbow')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
cont = ['total_bill','tip']
sns.pairplot(df,vars = cont)
plt.plot()
# Out:
# []

# %%
sns.pairplot(df,vars = cont,hue = 'sex')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(x = 'smoker',data = df)
plt.show()

# %%
sns.barplot(x = 'sex',y = 'total_bill',data = df)
plt.show()

# %%
sns.catplot(x = 'sex',y = 'total_bill',data = df)
plt.show()

# %%
sns.catplot(x = 'sex',y = 'total_bill',data = df,kind = 'bar')
plt.show()

# %%
sns.catplot(x = 'day',y = 'total_bill',data = df,kind = 'bar',hue = 'size')
plt.show()

# %%
sns.catplot(x = 'smoker',y = 'tip',data = df,kind = 'bar',order = ['yes','no'],hue = 'size')
plt.show()
